# %% [markdown]
# COVID DATA AUSTRALIA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv(r"..COVID-19_Data-master\Data\COVID_Data_Hub.csv")
data.head()
# Out:
#          date  confirmed  deaths  tests  positives  recovered  hosp  icu  \
# 0  2020-01-25          4       0      0          0          0     0    0
# 1  2020-01-26          4       0      0          0          0     0    0
# 2  2020-01-27          5       0      0          0          0     0    0
# 3  2020-01-28          5       0      0          0          0     0    0
# 4  2020-01-29          9       0      0          0          0     0    0
#
#    vent  vaccines  people_vaccinated  people_fully_vaccinated  population  \
# 0     0         0                  0                        0    25459470
# 1     0         0                  0                        0    25459470
# 2     0         0                  0                        0    25459470
# 3     0         0                  0                        0    25459470
# 4     0         0                  0                        0    25459470
#
#    administrative_area_level administrative_area_level_1  \
# ...

# %%
data.columns
# Out:
# Index(['date', 'confirmed', 'deaths', 'tests', 'positives', 'recovered',
#        'hosp', 'icu', 'vent', 'vaccines', 'people_vaccinated',
#        'people_fully_vaccinated', 'population', 'administrative_area_level',
#        'administrative_area_level_1', 'administrative_area_level_2',
#        'administrative_area_level_3', 'id'],
#       dtype='object')

# %%
sns.relplot(x = "date",y = "positives",hue = "recovered",data = data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['date', 'confirmed', 'deaths', 'tests', 'positives', 'recovered',
#        'hosp', 'icu', 'vent', 'vaccines', 'people_vaccinated',
#        'people_fully_vaccinated', 'population', 'administrative_area_level',
#        'administrative_area_level_1', 'administrative_area_level_2',
#        'administrative_area_level_3', 'id'],
#       dtype='object')

# %%
sns.relplot(x = 'date' ,y = 'deaths', data=data )

# %%
sns.catplot(x = 'confirmed',y = 'icu', data=data)
